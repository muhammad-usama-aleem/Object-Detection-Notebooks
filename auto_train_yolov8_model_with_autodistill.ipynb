# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammad-usama-aleem/Roboflow-Object-Detection-Notebooks/blob/main/auto_train_yolov8_model_with_autodistill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://ik.imagekit.io/roboflow/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Auto Train YOLOv8 Model with Autodistill
#
# Autodistill uses big, slower foundation models to train small, faster supervised models. Using `autodistill`, you can go from unlabeled images to inference on a custom model running at the edge with no human intervention in between.
#
# ![Autodistill Steps](https://media.roboflow.com/open-source/autodistill/steps.jpg)
#
# As foundation models get better and better they will increasingly be able to augment or replace humans in the labeling process. We need tools for steering, utilizing, and comparing these models. Additionally, these foundation models are big, expensive, and often gated behind private APIs. For many production use-cases, we need models that can run cheaply and in realtime at the edge.
#
# ![Autodistill Connections](https://media.roboflow.com/open-source/autodistill/connections.jpg)
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Image dataset preperation
# - Autolabel dataset
# - Train target model
# - Evaluate target model
# - Run video inference
# - Upload dataset and model to Roboflow (comming soon)
#
# ## 🔥 Let's begin!

# %% [markdown]
# ## ⚡ Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Dec 10 15:11:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 🧪 Install autodistill
#
# **NOTE:** Autodistill is an ecosystem for using big, slower foundation models to train small, faster supervised models. Each Base, as well as the Target model, has its own separate repository and pip package.

# %%
# !pip install -q \
autodistill \
autodistill-grounded-sam \
autodistill-yolov8 \
roboflow \
supervision==0.9.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 24.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 19.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## 🖼️ Image dataset preperation
#
# **NOTE:** To use Autodistill all you need to have is a set of images that you want to automatically annotate, and use for target model training.

# %%
# !mkdir {HOME}/images

# %% [markdown]
# **NOTE:** If you want to build YOLOv8 on your data make sure to upload it into `images` directory that we just created. ☝️

# %% [markdown]
# ### Download raw videos (optional)
#
# **NOTE:** In this tutorial, we will start with a directory containing video files and I will show you how to turn it into a ready-to-use collection of images. If you are working with your images, you can skip this part.

# %%
# !mkdir {HOME}/videos
# %cd {HOME}/videos

# download zip file containing videos
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt" -O milk.zip && rm -rf /tmp/cookies.txt

# unzip videos
# !unzip milk.zip
# Out:
# /content/videos
# --2023-12-10 15:12:07--  https://docs.google.com/uc?export=download&confirm=t&id=1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt
# Resolving docs.google.com (docs.google.com)... 142.250.4.139, 142.250.4.113, 142.250.4.102, ...
# Connecting to docs.google.com (docs.google.com)|142.250.4.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ft6dcqclb6sokjemkdonevfnu7e9duj9/1702221075000/04309230031174164349/*/1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt?e=download&uuid=973f643f-17a9-454d-9973-71f04ea47af6 [following]
# Warning: wildcards not supported in HTTP.
# --2023-12-10 15:12:07--  https://doc-08-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ft6dcqclb6sokjemkdonevfnu7e9duj9/1702221075000/04309230031174164349/*/1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt?e=download&uuid=973f643f-17a9-454d-9973-71f04ea47af6
# Resolving doc-08-ag-docs.googleusercontent.com (doc-08-ag-docs.googleusercontent.com)... 74.125.130.132, 2404:6800:4003:c01::84
# Connecting to doc-08-ag-docs.googleusercontent.com (doc-08-ag-docs.googleusercontent.com)|74.125.130.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1192719976 (1.1G) [application/zip]
# Saving to: ‘milk.zip’
#
# milk.zip            100%[===================>]   1.11G  49.5MB/s    in 25s
#
# 2023-12-10 15:12:33 (45.1 MB/s) - ‘milk.zip’ saved [1192719976/1192719976]
#
# Archive:  milk.zip
#   inflating: milk-video-1.mov
#   inflating: milk-video-2.mov
#   inflating: milk-video-3.mov
#   inflating: milk-video-4.mov
#   inflating: milk-video-5.mov
#   inflating: milk-video-6.mov
#   inflating: milk-video-7.mov
#   inflating: milk-video-8.mov

# %% [markdown]
# ### Convert videos into images (optional)
#
# **NOTE:** Now, let's convert videos into images. By default, the code below saves every `10th` frame from each video. You can change this by manipulating the value of the `FRAME_STRIDE` parameter.

# %%
VIDEO_DIR_PATH = f"{HOME}/videos"
IMAGE_DIR_PATH = f"{HOME}/images"
FRAME_STRIDE = 13

# %% [markdown]
# **NOTE:** Notice that we put two of our videos aside so that we can use them at the end of the notebook to evaluate our model.

# %%
import supervision as sv
from tqdm.notebook import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])

print(video_paths)

for video_path in tqdm(video_paths):
    video_name = video_path.stem
    image_name_pattern = video_name + "-{:05d}.png"
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            sink.save_image(image=image)
# Out:
# [PosixPath('/content/videos/milk-video-5.mov'), PosixPath('/content/videos/milk-video-8.mov'), PosixPath('/content/videos/milk-video-2.mov'), PosixPath('/content/videos/milk-video-7.mov'), PosixPath('/content/videos/milk-video-4.mov'), PosixPath('/content/videos/milk-video-3.mov'), PosixPath('/content/videos/milk-video-6.mov'), PosixPath('/content/videos/milk-video-1.mov')]
#   0%|          | 0/8 [00:00<?, ?it/s]

# %% [markdown]
# ### Display image sample
#
# **NOTE:** Before we start building a model with autodistill, let's make sure we have everything we need.

# %%
import supervision as sv

image_paths = sv.list_files_with_extensions(
    directory=IMAGE_DIR_PATH,
    extensions=["png", "jpg", "jpg"])

print('image count:', len(image_paths))
# Out:
# image count: 154

# %% [markdown]
# **NOTE:** We can also plot sample of our image dataset.

# %%
IMAGE_DIR_PATH = f"{HOME}/images"
SAMPLE_SIZE = 16
SAMPLE_GRID_SIZE = (4, 4)
SAMPLE_PLOT_SIZE = (16, 16)

# %%
import cv2
import supervision as sv

titles = [
    image_path.stem
    for image_path
    in image_paths[:SAMPLE_SIZE]]
images = [
    cv2.imread(str(image_path))
    for image_path
    in image_paths[:SAMPLE_SIZE]]

sv.plot_images_grid(images=images, titles=titles, grid_size=SAMPLE_GRID_SIZE, size=SAMPLE_PLOT_SIZE)

# %% [markdown]
# ## 🏷️ Autolabel dataset

# %% [markdown]
# ### Define ontology
#
# **Ontology** - an Ontology defines how your Base Model is prompted, what your Dataset will describe, and what your Target Model will predict. A simple Ontology is the CaptionOntology which prompts a Base Model with text captions and maps them to class names. Other Ontologies may, for instance, use a CLIP vector or example images instead of a text caption.

# %%
from autodistill.detection import CaptionOntology

ontology=CaptionOntology({
    "blue cap": "blue cap",
    "milk bottle": "milk bottle"
})

# %% [markdown]
# ### Initiate base model and autolabel
#
# **Base Model** - A Base Model is a large foundation model that knows a lot about a lot. Base models are often multimodal and can perform many tasks. They're large, slow, and expensive. Examples of Base Models are GroundedSAM and GPT-4's upcoming multimodal variant. We use a Base Model (along with unlabeled input data and an Ontology) to create a Dataset.

# %%
DATASET_DIR_PATH = f"{HOME}/images"

# %% [markdown]
# **NOTE:** Base Models are slow... Make yourself a coffee, autolabeing may take a while. ☕

# %%
from autodistill_grounded_sam import GroundedSAM

base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH,
    extension=".png",
    output_folder=DATASET_DIR_PATH)
# Out:
# trying to load grounding dino directly
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# final text_encoder_type: bert-base-uncased
# Labeling /content/images/milk-video-6-00004.png:   0%|          | 0/154 [00:00<?, ?it/s]The `device` argument is deprecated and will be removed in v5 of Transformers.
# torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
# None of the inputs have requires_grad=True. Gradients will be None
# The `device` argument is deprecated and will be removed in v5 of Transformers.
# torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
# None of the inputs have requires_grad=True. Gradients will be None
# Labeling /content/images/milk-video-5-00011.png: 100%|██████████| 154/154 [09:49<00:00,  3.83s/it]
# Labeled dataset created - ready for distillation.

# %% [markdown]
# ### Display dataset sample
#
# **Dataset** - a Dataset is a set of auto-labeled data that can be used to train a Target Model. It is the output generated by a Base Model.

# %%
ANNOTATIONS_DIRECTORY_PATH = f"{HOME}/images/train/labels"
IMAGES_DIRECTORY_PATH = f"{HOME}/images/train/images"
DATA_YAML_PATH = f"{HOME}/images/data.yaml"

# %%
import supervision as sv

dataset = sv.DetectionDataset.from_yolo(
    images_directory_path=IMAGES_DIRECTORY_PATH,
    annotations_directory_path=ANNOTATIONS_DIRECTORY_PATH,
    data_yaml_path=DATA_YAML_PATH)

len(dataset)

# %%
import supervision as sv

image_names = list(dataset.images.keys())[:SAMPLE_SIZE]

mask_annotator = sv.MaskAnnotator()
box_annotator = sv.BoxAnnotator()

images = []
for image_name in image_names:
    image = dataset.images[image_name]
    annotations = dataset.annotations[image_name]
    labels = [
        dataset.classes[class_id]
        for class_id
        in annotations.class_id]
    annotates_image = mask_annotator.annotate(
        scene=image.copy(),
        detections=annotations)
    annotates_image = box_annotator.annotate(
        scene=annotates_image,
        detections=annotations,
        labels=labels)
    images.append(annotates_image)

sv.plot_images_grid(
    images=images,
    titles=image_names,
    grid_size=SAMPLE_GRID_SIZE,
    size=SAMPLE_PLOT_SIZE)

# %% [markdown]
# ## 🔥 Train target model - YOLOv8
#
# **Target Model** - a Target Model is a supervised model that consumes a Dataset and outputs a distilled model that is ready for deployment. Target Models are usually small, fast, and fine-tuned to perform a specific task very well (but they don't generalize well beyond the information described in their Dataset). Examples of Target Models are YOLOv8 and DETR.

# %%
# %cd {HOME}

from autodistill_yolov8 import YOLOv8

target_model = YOLOv8("yolov8l.pt")
target_model.train(DATA_YAML_PATH, epochs=100)

# %% [markdown]
# ## ⚖️ Evaluate target model
#
# **NOTE:** As with the regular YOLOv8 training, we can now take a look at artifacts stored in `runs` directory.

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## 🎬 Run Inference on a video

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
INPUT_VIDEO_PATH = TEST_VIDEO_PATHS[0]
OUTPUT_VIDEO_PATH = f"{HOME}/output.mp4"
TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train/weights/best.pt"

# %%
# !yolo predict model={TRAINED_MODEL_PATH} source={INPUT_VIDEO_PATH}
# Out:
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 100.8ms
# video 1/1 (2/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (3/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (4/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (5/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 8.9ms
# video 1/1 (6/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (7/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.4ms
# video 1/1 (8/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (9/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (10/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.4ms
# video 1/1 (11/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (12/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (13/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (14/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (15/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (16/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (17/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (18/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (19/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (20/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (21/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (22/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (23/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (24/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (25/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (26/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (27/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (28/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (29/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 7.1ms
# video 1/1 (30/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (31/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 7.3ms
# video 1/1 (32/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (33/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (34/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (35/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (36/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (37/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 8.1ms
# video 1/1 (38/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 8.2ms
# video 1/1 (39/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 6.6ms
# video 1/1 (40/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 6.6ms
# video 1/1 (41/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (42/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 6.6ms
# video 1/1 (43/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (44/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (45/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 6.6ms
# video 1/1 (46/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (47/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (48/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (49/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.7ms
# video 1/1 (50/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (51/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (52/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 7.4ms
# video 1/1 (53/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (54/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (55/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (56/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (57/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (58/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.9ms
# video 1/1 (59/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (60/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (61/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (62/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (63/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (64/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (65/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (66/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (67/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (68/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.9ms
# video 1/1 (69/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.5ms
# video 1/1 (70/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (71/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (72/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (73/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (74/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (75/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (76/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (77/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 8.3ms
# video 1/1 (78/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 9.3ms
# video 1/1 (79/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.9ms
# video 1/1 (80/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (81/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (82/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (83/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (84/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (85/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (86/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (87/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.7ms
# video 1/1 (88/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 7.1ms
# video 1/1 (89/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (90/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.7ms
# video 1/1 (91/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (92/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (93/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (94/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.7ms
# video 1/1 (95/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (96/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (97/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.9ms
# video 1/1 (98/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 7.9ms
# video 1/1 (99/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 7.7ms
# video 1/1 (100/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.8ms
# video 1/1 (101/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.7ms
# video 1/1 (102/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.5ms
# video 1/1 (103/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (104/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (105/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (106/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (107/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (108/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 7.1ms
# video 1/1 (109/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (110/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (111/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (112/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (113/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (114/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (115/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.7ms
# video 1/1 (116/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (117/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.7ms
# video 1/1 (118/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 8.5ms
# video 1/1 (119/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.7ms
# video 1/1 (120/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (121/397) /content/videos/milk-video-8.mov: 384x640 7 bottles, 2 caps, 6.6ms
# video 1/1 (122/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (123/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.7ms
# video 1/1 (124/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.9ms
# video 1/1 (125/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (126/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.7ms
# video 1/1 (127/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.7ms
# video 1/1 (128/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (129/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 7.3ms
# video 1/1 (130/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (131/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (132/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (133/397) /content/videos/milk-video-8.mov: 384x640 3 bottles, 3 caps, 6.6ms
# video 1/1 (134/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (135/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (136/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.7ms
# video 1/1 (137/397) /content/videos/milk-video-8.mov: 384x640 3 bottles, 2 caps, 6.8ms
# video 1/1 (138/397) /content/videos/milk-video-8.mov: 384x640 3 bottles, 3 caps, 6.5ms
# video 1/1 (139/397) /content/videos/milk-video-8.mov: 384x640 3 bottles, 2 caps, 6.9ms
# video 1/1 (140/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (141/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (142/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (143/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (144/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (145/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.8ms
# video 1/1 (146/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 7.7ms
# video 1/1 (147/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 8.8ms
# video 1/1 (148/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (149/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 7.4ms
# video 1/1 (150/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (151/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.8ms
# video 1/1 (152/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (153/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 7.1ms
# video 1/1 (154/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.9ms
# video 1/1 (155/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (156/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (157/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 7.2ms
# video 1/1 (158/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.7ms
# video 1/1 (159/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (160/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.7ms
# video 1/1 (161/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (162/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (163/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (164/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (165/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (166/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.7ms
# video 1/1 (167/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (168/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.7ms
# video 1/1 (169/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.7ms
# video 1/1 (170/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.8ms
# video 1/1 (171/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.7ms
# video 1/1 (172/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (173/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (174/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (175/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (176/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.5ms
# video 1/1 (177/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 6.6ms
# video 1/1 (178/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 6.6ms
# video 1/1 (179/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 6.6ms
# video 1/1 (180/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 6.6ms
# video 1/1 (181/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 6.5ms
# video 1/1 (182/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (183/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 6.5ms
# video 1/1 (184/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 8.2ms
# video 1/1 (185/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 1 cap, 6.6ms
# video 1/1 (186/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 6.6ms
# video 1/1 (187/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 6.6ms
# video 1/1 (188/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 6.6ms
# video 1/1 (189/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 6.6ms
# video 1/1 (190/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 1 cap, 6.6ms
# video 1/1 (191/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (192/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (193/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (194/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.7ms
# video 1/1 (195/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 7.2ms
# video 1/1 (196/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (197/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (198/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (199/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (200/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.5ms
# video 1/1 (201/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.5ms
# video 1/1 (202/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (203/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (204/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.7ms
# video 1/1 (205/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (206/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (207/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (208/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (209/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (210/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.7ms
# video 1/1 (211/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.5ms
# video 1/1 (212/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (213/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (214/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.5ms
# video 1/1 (215/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (216/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (217/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 7.0ms
# video 1/1 (218/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.7ms
# video 1/1 (219/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.7ms
# video 1/1 (220/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (221/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (222/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.9ms
# video 1/1 (223/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.7ms
# video 1/1 (224/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (225/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (226/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.5ms
# video 1/1 (227/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.5ms
# video 1/1 (228/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (229/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (230/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 4 caps, 6.5ms
# video 1/1 (231/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.5ms
# video 1/1 (232/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (233/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (234/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (235/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (236/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (237/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.7ms
# video 1/1 (238/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.7ms
# video 1/1 (239/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.9ms
# video 1/1 (240/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.7ms
# video 1/1 (241/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (242/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (243/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (244/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 8.3ms
# video 1/1 (245/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 7.0ms
# video 1/1 (246/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.7ms
# video 1/1 (247/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.7ms
# video 1/1 (248/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.7ms
# video 1/1 (249/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.7ms
# video 1/1 (250/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (251/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.5ms
# video 1/1 (252/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 8.0ms
# video 1/1 (253/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (254/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.7ms
# video 1/1 (255/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (256/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (257/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (258/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (259/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.7ms
# video 1/1 (260/397) /content/videos/milk-video-8.mov: 384x640 7 bottles, 3 caps, 6.6ms
# video 1/1 (261/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (262/397) /content/videos/milk-video-8.mov: 384x640 7 bottles, 3 caps, 6.6ms
# video 1/1 (263/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (264/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 8.1ms
# video 1/1 (265/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.9ms
# video 1/1 (266/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (267/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (268/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (269/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.5ms
# video 1/1 (270/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.7ms
# video 1/1 (271/397) /content/videos/milk-video-8.mov: 384x640 7 bottles, 3 caps, 6.5ms
# video 1/1 (272/397) /content/videos/milk-video-8.mov: 384x640 7 bottles, 3 caps, 6.5ms
# video 1/1 (273/397) /content/videos/milk-video-8.mov: 384x640 8 bottles, 4 caps, 6.8ms
# video 1/1 (274/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (275/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 4 caps, 6.5ms
# video 1/1 (276/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 5 caps, 8.0ms
# video 1/1 (277/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 4 caps, 6.6ms
# video 1/1 (278/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 4 caps, 6.7ms
# video 1/1 (279/397) /content/videos/milk-video-8.mov: 384x640 3 bottles, 3 caps, 6.6ms
# video 1/1 (280/397) /content/videos/milk-video-8.mov: 384x640 2 bottles, 3 caps, 6.5ms
# video 1/1 (281/397) /content/videos/milk-video-8.mov: 384x640 3 bottles, 3 caps, 7.1ms
# video 1/1 (282/397) /content/videos/milk-video-8.mov: 384x640 3 bottles, 3 caps, 6.6ms
# video 1/1 (283/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (284/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 7.0ms
# video 1/1 (285/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (286/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (287/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (288/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (289/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (290/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (291/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (292/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (293/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.6ms
# video 1/1 (294/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 3 caps, 6.7ms
# video 1/1 (295/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (296/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.7ms
# video 1/1 (297/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.8ms
# video 1/1 (298/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (299/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.5ms
# video 1/1 (300/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.5ms
# video 1/1 (301/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (302/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.5ms
# video 1/1 (303/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.5ms
# video 1/1 (304/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.4ms
# video 1/1 (305/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.5ms
# video 1/1 (306/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.5ms
# video 1/1 (307/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.5ms
# video 1/1 (308/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.5ms
# video 1/1 (309/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.5ms
# video 1/1 (310/397) /content/videos/milk-video-8.mov: 384x640 6 bottles, 2 caps, 6.6ms
# video 1/1 (311/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (312/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (313/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (314/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (315/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (316/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (317/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.4ms
# video 1/1 (318/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.6ms
# video 1/1 (319/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 6.5ms
# video 1/1 (320/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 8.2ms
# video 1/1 (321/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (322/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 7.0ms
# video 1/1 (323/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 7.5ms
# video 1/1 (324/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (325/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (326/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (327/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (328/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (329/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (330/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.9ms
# video 1/1 (331/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (332/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.9ms
# video 1/1 (333/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (334/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (335/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (336/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (337/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (338/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 2 caps, 7.8ms
# video 1/1 (339/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (340/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (341/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.7ms
# video 1/1 (342/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (343/397) /content/videos/milk-video-8.mov: 384x640 3 bottles, 3 caps, 6.7ms
# video 1/1 (344/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (345/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 4 caps, 6.6ms
# video 1/1 (346/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (347/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (348/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (349/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (350/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (351/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (352/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (353/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (354/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (355/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (356/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (357/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (358/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (359/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (360/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (361/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 8.7ms
# video 1/1 (362/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (363/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 8.2ms
# video 1/1 (364/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (365/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (366/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (367/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (368/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.5ms
# video 1/1 (369/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (370/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (371/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 3 caps, 6.6ms
# video 1/1 (372/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (373/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.5ms
# video 1/1 (374/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (375/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (376/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (377/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.5ms
# video 1/1 (378/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (379/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.8ms
# video 1/1 (380/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (381/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (382/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (383/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (384/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (385/397) /content/videos/milk-video-8.mov: 384x640 5 bottles, 4 caps, 6.6ms
# video 1/1 (386/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 4 caps, 6.6ms
# video 1/1 (387/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 4 caps, 6.6ms
# video 1/1 (388/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 3 caps, 6.6ms
# video 1/1 (389/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (390/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (391/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.6ms
# video 1/1 (392/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (393/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (394/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (395/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (396/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# video 1/1 (397/397) /content/videos/milk-video-8.mov: 384x640 4 bottles, 2 caps, 6.5ms
# Speed: 0.5ms preprocess, 6.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# ## Export Model to Custom Python Script and Project

# %%
yolo export model=yolov8n.pt
